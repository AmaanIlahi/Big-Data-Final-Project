-- %% [markdown]
-- ## Live High-Risk Transactions (Core Demo)

-- %%
SELECT
  event_time,
  customer_id,
  merchant_id,
  amount,
  risk_score
FROM workspace.default.streaming_scored_transactions
WHERE risk_score >= 70
ORDER BY event_time DESC
LIMIT 50;
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- ## Live Risk by Merchant (Anomaly Signal)

-- %%
SELECT
  merchant_id,
  COUNT(*) AS transaction_count,
  ROUND(AVG(risk_score), 2) AS avg_risk_score
FROM streaming_scored_transactions
GROUP BY merchant_id
ORDER BY avg_risk_score DESC;
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- ## Risk Over Time (Streaming Effect)

-- %%
SELECT
  date_trunc('minute', event_time) AS minute,
  ROUND(AVG(risk_score), 2) AS avg_risk
FROM streaming_scored_transactions
GROUP BY minute
ORDER BY minute;
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- ## Risk by Customer Cluster (Streaming + ML)

-- %%
SELECT
  c.prediction AS cluster_id,
  COUNT(*) AS transaction_count,
  ROUND(AVG(s.risk_score), 2) AS avg_risk
FROM streaming_scored_transactions s
JOIN customer_clusters c
  ON s.customer_id = c.customer_id
GROUP BY c.prediction
ORDER BY avg_risk DESC;
-- Out:
-- Databricks visualization. Run in Databricks to view.

-- %% [markdown]
-- ## Cluster Sizes (Context)

-- %%
SELECT
  prediction AS cluster_id,
  COUNT(*) AS customers
FROM customer_clusters
GROUP BY prediction;
-- Out:
-- Databricks visualization. Run in Databricks to view.
